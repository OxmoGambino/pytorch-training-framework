# %% [markdown]
# # Extraction de CIFAR10

# %%
import torch
import torchvision
import torchvision.transforms as transforms


transform = transforms.Compose([transforms.ToTensor(),transforms.Normalize((0.5,0.5,0.5), (0.5,0.5,0.5))])

trainset = torchvision.datasets.CIFAR10(root='./data',train=True,download=True,transform=transform)
# Out:
# 100%|██████████| 170M/170M [00:08<00:00, 19.1MB/s]

# %%
print("Je ne sais pas quoi faire de ce dataset de con")
# Out:
# Je ne sais pas quoi faire de ce dataset de con

# %%
import matplotlib.pyplot as plt
import numpy as np
from torch.utils.data import DataLoader

trainloader = DataLoader(trainset, batch_size=4, shuffle=True)

images, labels = next(iter(trainloader))

# annuler la normalisation
images = images / 2 + 0.5

fig, axs = plt.subplots(2, 2, figsize=(8,8))

for i in range(4):
    img = images[i].numpy()
    img = np.transpose(img, (1,2,0))
    
    axs[i//2, i%2].imshow(img)
    axs[i//2, i%2].set_title(trainset.classes[labels[i]])
    axs[i//2, i%2].axis("off")

plt.show()
